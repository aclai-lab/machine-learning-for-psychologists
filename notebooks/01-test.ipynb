# %%
using CSV
using DataFrames
using Tables
# Out:
# ArgumentError: Package StatFiles not found in current path.
# - Run `import Pkg; Pkg.add("StatFiles")` to install the StatFiles package.
#
# Stacktrace:
#  [1] macro expansion
#    @ ./loading.jl:2403 [inlined]
#  [2] macro expansion
#    @ ./lock.jl:376 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:2386
#  [4] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:2362
#  [5] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
# 1. Carica il file .sav
# Sostituisci "input.sav" con il percorso del tuo file
data_spss = read_sav("input.sav")

# 2. Converte in DataFrame (opzionale se read_sav restituisce già un DataFrame)
df = DataFrame(data_spss)

# 3. Salva come file CSV
CSV.write("output.csv", df)
