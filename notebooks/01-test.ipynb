# %%
using CSV
using DataFrames
using ReadStatTables
using StatFiles, FileIO

# %%
# 1. Carica il file .sav
# Sostituisci "input.sav" con il percorso del tuo file
df = DataFrame(readstat("../datasets/not_onco_combined_dataset.sav"))

# 3. Salva come file CSV
CSV.write("output.csv", df)
# Out:
# UndefVarError: `load` not defined in `ReadStatTables`
# Suggestion: check for spelling errors or missing imports.
# Hint: a global variable of this name also exists in FileIO.
#     - Also exported by StatFiles.
#
# Stacktrace:
#  [1] getproperty(x::Module, f::Symbol)
#    @ Base ./Base_compiler.jl:47
#  [2] top-level scope
#    @ In[17]:3
#  [3] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489
